# %%
import pandas as pd
import numpy as np

# %%
from pandas import DataFrame

# %%
yob = ['name', 'gender', 'quantity']

# %%
data = pd.read_table('yob1880.txt', sep =',', engine = 'python', names = yob)
data
# Out:
#            name gender  quantity
# 0          Mary      F      7065
# 1          Anna      F      2604
# 2          Emma      F      2003
# 3     Elizabeth      F      1939
# 4        Minnie      F      1746
# 5      Margaret      F      1578
# 6           Ida      F      1472
# 7         Alice      F      1414
# 8        Bertha      F      1320
# 9         Sarah      F      1288
# 10        Annie      F      1258
# 11        Clara      F      1226
# 12         Ella      F      1156
# 13     Florence      F      1063
# 14         Cora      F      1045
# 15       Martha      F      1040
# 16        Laura      F      1012
# 17       Nellie      F       995
# 18        Grace      F       982
# 19       Carrie      F       949
# 20        Maude      F       858
# 21        Mabel      F       808
# 22       Bessie      F       794
# 23       Jennie      F       793
# 24     Gertrude      F       787
# 25        Julia      F       783
# 26       Hattie      F       769
# ...

# %%
#data['year'] = np.nan
for i in range(1881,2011):
    df = pd.read_table('yob%d.txt' %i, sep = ',', engine = 'python', names = yob)
    data = pd.concat([data, df])
# Out:
# C:\Users\Konstantin\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   after removing the cwd from sys.path.

# %%
data
# Out:
#       gender       name  quantity  year
# 0          F       Mary      7065   NaN
# 1          F       Anna      2604   NaN
# 2          F       Emma      2003   NaN
# 3          F  Elizabeth      1939   NaN
# 4          F     Minnie      1746   NaN
# 5          F   Margaret      1578   NaN
# 6          F        Ida      1472   NaN
# 7          F      Alice      1414   NaN
# 8          F     Bertha      1320   NaN
# 9          F      Sarah      1288   NaN
# 10         F      Annie      1258   NaN
# 11         F      Clara      1226   NaN
# 12         F       Ella      1156   NaN
# 13         F   Florence      1063   NaN
# 14         F       Cora      1045   NaN
# 15         F     Martha      1040   NaN
# 16         F      Laura      1012   NaN
# 17         F     Nellie       995   NaN
# 18         F      Grace       982   NaN
# 19         F     Carrie       949   NaN
# 20         F      Maude       858   NaN
# 21         F      Mabel       808   NaN
# ...
